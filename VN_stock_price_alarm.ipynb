# %% [markdown]
# <a href="https://colab.research.google.com/github/Quanghoaai/Podo/blob/main/VN_stock_price_alarm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yFinance
import yfinance as yf
# Out:
# Requirement already satisfied: yFinance in /usr/local/lib/python3.11/dist-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yFinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yFinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yFinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yFinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yFinance) (5.3.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yFinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yFinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yFinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yFinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yFinance) (4.13.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yFinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yFinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yFinance) (4.12.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yFinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yFinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yFinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yFinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yFinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yFinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yFinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yFinance) (2025.1.31)

# %%
import plotly.graph_objs as go

# %%
usd_try = yf.Ticker("MSB.VN") #Mã TRY=X

# %%
#usd_try.info

# %%
#Günlük periyotta 1 dakikalık aralıklarla veriyi çekiyorum. Verim Pandas Dataframe olarak geliyor.
df = yf.download(tickers='MSB.VN', period='1d', interval='1m')
type(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# pandas.core.frame.DataFrame

# %%
import yfinance as yf
import pandas as pd # Import pandas with the alias 'pd'

#Günlük periyotta 1 dakikalık aralıklarla veriyi çekiyorum. Verim Pandas Dataframe olarak geliyor.
df = yf.download(tickers='MSB.VN', period='1d', interval='1m')
type(df)

# To check if it's a pandas DataFrame, you can use:
isinstance(df, pd.DataFrame) # Use pd.DataFrame since pandas is imported as pd
# Out:
# [*********************100%***********************]  1 of 1 completed
# True

# %%
df # Veri setinde son satır için tüm değerleri anlık veri olarak çektiği için değerler aynı görünmekte.
# Out:
# Price                        Close     High      Low     Open Volume
# Ticker                      MSB.VN   MSB.VN   MSB.VN   MSB.VN MSB.VN
# Datetime
# 2025-02-18 02:15:00+00:00  11400.0  11400.0  11400.0  11400.0      0
# 2025-02-18 02:16:00+00:00  11450.0  11450.0  11450.0  11450.0    400
# 2025-02-18 02:18:00+00:00  11450.0  11450.0  11450.0  11450.0    500
# 2025-02-18 02:19:00+00:00  11400.0  11400.0  11400.0  11400.0   5000
# 2025-02-18 02:20:00+00:00  11400.0  11400.0  11400.0  11400.0   1500
# ...                            ...      ...      ...      ...    ...
# 2025-02-18 07:18:00+00:00  11450.0  11450.0  11450.0  11450.0   4200
# 2025-02-18 07:20:00+00:00  11450.0  11450.0  11450.0  11450.0  16300
# 2025-02-18 07:21:00+00:00  11450.0  11450.0  11400.0  11450.0  42200
# 2025-02-18 07:22:00+00:00  11400.0  11450.0  11400.0  11450.0   5300
# 2025-02-18 07:23:00+00:00  11450.0  11450.0  11450.0  11450.0      0
#
# [186 rows x 5 columns]

# %%
print(df.iloc[len(df['Close'])-1])
# Out:
# Price   Ticker
# Close   MSB.VN    11450.0
# High    MSB.VN    11450.0
# Low     MSB.VN    11450.0
# Open    MSB.VN    11450.0
# Volume  MSB.VN        0.0
# Name: 2025-02-18 07:23:00+00:00, dtype: float64

# %%
close_value=(df['Close'].iloc[len(df['Close'])-1]) #Close sutünunun son verisini kapanış değeri olarak atıyorum.
print(close_value)
# Out:
# Ticker
# MSB.VN    11450.0
# Name: 2025-02-18 07:23:00+00:00, dtype: float64

# %%
from datetime import datetime

#datetime tüm zaman birimlerini kapsamaktadır.
now = datetime.now()
#Veri saniyeye kadar indiği için bende buraya kadar alıyorum.
sys_date = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", sys_date)
# Out:
# date and time = 18/02/2025 07:41:48

# %%
def set_alarm(min_price,max_price):
  import yfinance as yf
  from datetime import datetime #Yahoo finance ve datetime tekrardan import edilmesi
  usd_try = yf.Ticker("MSB.VN") # İstenilen birim veya hisse kodunun yerleştirilmesi
  while True: # Fonksiyonun sonsuz döngüye sokulması
      data = yf.download(tickers='MSB.VN', period='1d', interval='1m')
      close_value=(data['Close'].iloc[len(data['Close'])-1]) #anlık kapanış değerinin alınması
      now = datetime.now()
      sys_date = now.strftime("%d/%m/%Y %H:%M:%S") # Güncel sistem zamanının alınması
      if close_value>=max_price: # max fiyat için koşul
        print("Price is  "  + str(close_value) + " . Time to sell. " +str(sys_date))
        break
      elif close_value<=min_price: # min fiyat için koşul
        print("Price is  "  + str(close_value) + " . Time to buy. " +str(sys_date))
        break
      else:
        print("Value of TRY is : " + str(close_value) +" at " +str(sys_date)) # koşullar sağlanmadıkça anlık değeri ve zamanı çıktı olarak görmek istiyorum.

# %%
def set_alarm(min_price,max_price):
  import yfinance as yf
  from datetime import datetime #Yahoo finance ve datetime tekrardan import edilmesi
  usd_try = yf.Ticker("MSB.VN") # İstenilen birim veya hisse kodunun yerleştirilmesi
  while True: # Fonksiyonun sonsuz döngüye sokulması
      data = yf.download(tickers='MSB.VN', period='1d', interval='1m')
      # Extract the last close value as a scalar using .item()
      close_value = data['Close'].iloc[-1].item()  # Access the last element and convert to scalar
      now = datetime.now()
      sys_date = now.strftime("%d/%m/%Y %H:%M:%S") # Güncel sistem zamanının alınması
      if close_value>=max_price: # max fiyat için koşul
        print("Price is  "  + str(close_value) + " . Time to sell. " +str(sys_date))
        break
      elif close_value<=min_price: # min fiyat için koşul
        print("Price is  "  + str(close_value) + " . Time to buy. " +str(sys_date))
        break
      else:
        print("Value of TRY is : " + str(close_value) +" at " +str(sys_date)) # koşullar sağlanmadıkça anlık değeri ve zamanı çıktı olarak görmek istiyorum.

# %%
set_alarm(11.25,11.40)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price is  11450.0 . Time to sell. 18/02/2025 07:42:22
