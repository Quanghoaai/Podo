# %% [markdown]
# <a href="https://colab.research.google.com/github/Quanghoaai/Podo/blob/main/Test_d%C3%B9ng_secret_key_v%C3%A0_%E1%BA%A9n_API_Gemini(_2_c%C3%A1ch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
env_path = "/content/drive/My Drive/.env"

# Ghi API Key vào file
with open(env_path, "w") as f:
    f.write("GEMINI_API_KEY=AIzaSyAL-kmaVVCaPJGPJ054dJdjj42sLQ210yc\n")

# %%
# Install the required library (if not already installed)
# !pip install --upgrade google-generativeai python-dotenv

import os
import google.generativeai as genai
from dotenv import load_dotenv

# Load environment variables from .env file
dotenv_path = "/content/drive/My Drive/.env"
if not os.path.exists(dotenv_path):
    raise FileNotFoundError(f".env file not found at {dotenv_path}. Please check the path.")

load_dotenv(dotenv_path)

# Retrieve the API key from environment variables
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise ValueError("API Key not found. Make sure your .env file contains GEMINI_API_KEY.")

# Configure the Google Generative AI client with the API key
genai.configure(api_key=api_key)

# Load the Gemini 2.0 Flash model
try:
    model = genai.GenerativeModel(model_name="gemini-2.0-flash")
except Exception as e:
    print("Error loading the model:", e)
    raise

# Define your prompt
question = "Làm thế nào để sử dụng Gemini API keys in secrets in Colab? Anwser me in Vietnamese language"

# Generate a response using the loaded model
try:
    response = model.generate_content(question)  # Use the question directly as the prompt
    print("Gemini API's response:", response.text)  # Accessing the response text
except Exception as e:
    print("Error occurred while generating content:", e)
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.25.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Gemini API's response: Để sử dụng Gemini API keys một cách an toàn trong Google Colab bằng cách lưu trữ chúng trong secrets, bạn có thể làm theo các bước sau:
#
# **1. Thiết lập Secrets trong Colab:**
#
# *   **Mở Google Colab:** Mở notebook Colab mà bạn muốn sử dụng Gemini API.
# *   **Truy cập Secrets:** Trong thanh công cụ bên trái, tìm biểu tượng "Secrets" (có hình ổ khóa). Nếu bạn không thấy, bạn có thể bật nó bằng cách vào "View" -> "Table of contents" -> "Enable secret manager".
# *   **Tạo Secrets:** Nhấp vào nút "Create secret".
# *   **Nhập tên Secrets:** Nhập một tên mô tả cho secrets của bạn (ví dụ: `GEMINI_API_KEY`).
# *   **Nhập giá trị Secrets:** Dán API key Gemini của bạn vào trường "Secret value".
# *   **Nhấp vào "Create Secret".**
# *   Lặp lại các bước trên nếu bạn có nhiều API key hoặc thông tin bí mật khác.
#
# **2. Truy cập Secrets trong Colab Code:**
#
# *   **Nhập thư viện `google.colab`:**  Để truy cập secrets, bạn cần nhập thư viện `google.colab`.
#
#     ```python
#     from google.colab import userdata
#     ```
#
# *   **Lấy giá trị Secrets:** Sử dụng hàm `userdata.get()` để lấy giá trị của secrets.
#
#     ```python
#     api_key = userdata.get('GEMINI_API_KEY')
#     ```
#
#     Thay thế `'GEMINI_API_KEY'` bằng tên secrets bạn đã tạo ở bước 1.
#
# *   **Sử dụng API Key:** Bây giờ bạn có thể sử dụng biến `api_key` trong code của bạn để gọi API Gemini.
#
#     ```python
#     # Ví dụ sử dụng api_key với thư viện google-generativeai (ví dụ)
#     import google.generativeai as genai
#
#     genai.configure(api_key=api_key)
#
#     model = genai.GenerativeModel('gemini-pro')
#     response = model.generate_content("Viết một câu chuyện ngắn.")
#     print(response.text)
#     ```
#
# **Ví dụ hoàn chỉnh:**
#
# ```python
# from google.colab import userdata
# import google.generativeai as genai
#
# # Lấy API key từ secrets
# api_key = userdata.get('GEMINI_API_KEY')
#
# # Cấu hình generativeai với API key
# genai.configure(api_key=api_key)
#
# # Chọn model Gemini
# model = genai.GenerativeModel('gemini-pro')
#
# # Tạo prompt và yêu cầu model tạo nội dung
# prompt = "Viết một bài thơ ngắn về hoa hồng."
# response = model.generate_content(prompt)
#
# # In kết quả
# print(response.text)
# ```
#
# **Lưu ý quan trọng:**
#
# *   **Bảo mật:** Việc sử dụng Colab Secrets giúp bạn tránh việc lưu trữ API key trực tiếp trong code của mình, làm tăng tính bảo mật.  Không bao giờ commit API key trực tiếp lên Github hoặc bất kỳ hệ thống kiểm soát phiên bản nào.
# *   **Giới hạn Secrets:** Colab có thể có giới hạn về số lượng secrets bạn có thể lưu trữ.
# *   **Quyền truy cập:** Secrets chỉ khả dụng cho người dùng được xác thực trong phiên Colab hiện tại.
# *   **Tên Secrets:** Chọn tên secrets mô tả và dễ nhớ để quản lý chúng tốt hơn.
#
# **Tóm tắt:**
#
# 1.  **Tạo Secrets** với tên và giá trị API key trong Colab.
# 2.  **Nhập `google.colab.userdata`**.
# 3.  **Sử dụng `userdata.get('Tên_Secrets')`** để lấy API key.
# 4.  **Sử dụng API key** trong code của bạn.
#
# Bằng cách làm theo các bước này, bạn có thể sử dụng Gemini API keys một cách an toàn và hiệu quả trong Google Colab. Chúc bạn thành công!

# %%
# Install the required library (if not already installed)
# !pip install --upgrade google-generativeai

import os
import google.generativeai as genai
from google.colab import userdata

# 1. Retrieve API Key from Colab Secrets
api_key = userdata.get('GOOGLE_API_KEY')  # Replace 'GEMINI_API_KEY' with your secret name

# 2. Handle Missing API Key
if not api_key:
    raise ValueError("API Key not found in Colab Secrets. Please create a secret named 'GEMINI_API_KEY'.")

# 3. Configure Google Generative AI Client
genai.configure(api_key=api_key)

# 4. Load the Gemini 2.0 Flash Model
try:
    model = genai.GenerativeModel(model_name="gemini-2.0-flash")
except Exception as e:
    print("Error loading the model:", e)
    raise

# 5. Define your prompt
question = "Hướng dẫn sử dụng nhanh n8n? Anwser me in Vietnamese language"

# 6. Generate a response using the loaded model
try:
    response = model.generate_content(question)  # Use the question directly as the prompt
    print("Gemini API's response:", response.text)  # Accessing the response text
except Exception as e:
    print("Error occurred while generating content:", e)
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.25.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Gemini API's response: Tuyệt vời! Đây là hướng dẫn sử dụng nhanh n8n, tập trung vào những điều cơ bản để bạn có thể bắt đầu ngay lập tức:
#
# **1. Cài đặt n8n:**
#
# *   **Dùng Docker (khuyến khích):** Đây là cách dễ nhất và nhanh nhất. Bạn cần cài Docker trước. Sau đó, chạy lệnh sau trong terminal:
#
#     ```bash
#     docker run -d -p 5678:5678 -v ~/.n8n:/home/node/.n8n n8nio/n8n
#     ```
#
#     *   `-d`: Chạy container ở chế độ nền (detached).
#     *   `-p 5678:5678`:  Ánh xạ cổng 5678 trên máy của bạn đến cổng 5678 trong container (nơi n8n chạy).
#     *   `-v ~/.n8n:/home/node/.n8n`:  Ánh xạ thư mục `~/.n8n` trên máy của bạn (nơi n8n lưu trữ dữ liệu) đến thư mục `/home/node/.n8n` trong container.  Điều này đảm bảo dữ liệu của bạn được giữ lại ngay cả khi container bị dừng hoặc xóa.
#     *   `n8nio/n8n`:  Hình ảnh Docker của n8n.
#
# *   **Cài đặt trực tiếp (Yêu cầu Node.js và npm):**
#
#     ```bash
#     npm install -g n8n
#     n8n
#     ```
#
# *   **Truy cập n8n:** Mở trình duyệt của bạn và truy cập `http://localhost:5678` (nếu bạn dùng Docker hoặc cài đặt trực tiếp).  Nếu bạn cài đặt trên một máy chủ từ xa, hãy thay `localhost` bằng địa chỉ IP hoặc tên miền của máy chủ đó.
#
# **2. Giao diện n8n:**
#
# *   **Canvas (Khu vực làm việc):**  Đây là nơi bạn sẽ xây dựng workflows của mình bằng cách kéo và thả các node.
# *   **Sidebar (Bên trái):**  Chứa các node có sẵn, được phân loại theo chức năng (ví dụ: Triggers, Utilities, Applications).
# *   **Toolbar (Phía trên):**  Chứa các nút để lưu, chạy, kích hoạt và quản lý workflow.
# *   **Property Panel (Bên phải):**  Hiển thị các tùy chọn cấu hình cho node đang được chọn.
#
# **3. Workflow cơ bản:**
#
# *   **Trigger Node:**  Workflow bắt đầu bằng một trigger node, xác định khi nào workflow sẽ chạy (ví dụ: mỗi khi có email mới, theo lịch trình).  Tìm trong mục "Triggers" trong sidebar.
# *   **Node:** Mỗi node thực hiện một hành động cụ thể (ví dụ: đọc email, gửi tin nhắn Slack, ghi dữ liệu vào Google Sheets).  Kéo và thả các node từ sidebar vào canvas.
# *   **Kết nối Node:**  Kết nối các node bằng cách kéo từ một điểm tròn ở cạnh phải của node đầu tiên đến một điểm tròn ở cạnh trái của node thứ hai.  Dữ liệu sẽ được truyền từ node này sang node khác theo đường kết nối.
#
# **4. Ví dụ đơn giản: "Hello World" với Manual Trigger và Set Node:**
#
# 1.  **Thêm Manual Trigger:** Kéo `Manual` từ mục "Triggers" vào canvas.  Node này cho phép bạn chạy workflow thủ công.
# 2.  **Thêm Set Node:** Kéo `Set` từ mục "Utilities" vào canvas. Node này cho phép bạn đặt giá trị cho các biến.
# 3.  **Kết nối Node:** Kết nối node `Manual` với node `Set`.
# 4.  **Cấu hình Set Node:** Trong Property Panel của node `Set`, nhấp vào "Add Expression".  Đặt "Name" là `message` và "Value" là `"Hello World!"`.
# 5.  **Thêm Return Node:** Kéo `Return` từ mục "Utilities" vào canvas.
# 6.  **Kết nối Node:** Kết nối node `Set` với node `Return`.
# 7.  **Cấu hình Return Node:**  Trong property panel của node `Return`, đặt `Return` thành `All`, và ở trường `Fields`, chọn `message`.
# 8.  **Chạy Workflow:** Nhấp vào nút "Execute Workflow" ở phía trên bên phải.
# 9.  **Xem kết quả:** Kết quả "Hello World!" sẽ xuất hiện trong bảng "Execution Result" ở phía dưới.
#
# **5. Các thao tác quan trọng:**
#
# *   **Lưu Workflow:** Nhấp vào nút "Save" ở phía trên bên phải để lưu workflow của bạn.
# *   **Kích hoạt Workflow:** Nhấp vào nút "Active" để kích hoạt workflow. Khi được kích hoạt, workflow sẽ tự động chạy theo trigger đã được cấu hình.
# *   **Xem Log:** Sử dụng tab "Executions" ở phía dưới để xem lịch sử chạy và log của các workflow.
# *   **Sử dụng biểu thức (Expressions):**  Biểu thức cho phép bạn truy cập và thao tác với dữ liệu từ các node trước đó. Ví dụ: `{{ $node["MyNode"].json["value"] }}` lấy giá trị "value" từ node có tên là "MyNode".
#
# **Lời khuyên:**
#
# *   **Bắt đầu từ những thứ đơn giản:** Đừng cố gắng xây dựng những workflow phức tạp ngay từ đầu. Bắt đầu với những ví dụ nhỏ và dần dần tăng độ phức tạp.
# *   **Sử dụng Documentation:** Trang chủ n8n có tài liệu rất chi tiết: [https://docs.n8n.io/](https://docs.n8n.io/)
# *   **Tham gia Cộng đồng:** Tham gia cộng đồng n8n trên diễn đàn hoặc Slack để được giúp đỡ và chia sẻ kiến thức.
#
# Chúc bạn thành công với n8n!  Nếu bạn có bất kỳ câu hỏi cụ thể nào, hãy cứ hỏi nhé.
